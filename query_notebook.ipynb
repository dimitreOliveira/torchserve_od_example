# %% [markdown]
# # Dependencies

# %%
from utils.visualization import make_request, visualize_detections

# %% [markdown]
# # Parameters

# %%
url = 'http://127.0.0.1:8080/predictions/fastrcnn'
image_path = './samples/man2.jpg'

# %% [markdown]
# ## Make request

# %%
detections = make_request(url, image_path)

# %% [markdown]
# ## Check response content

# %%
print(len(detections), detections)
# Out:
# 2 [{'person': [882.3184204101562, 35.57386779785156, 1847.2567138671875, 2697.3681640625], 'score': 0.9997232556343079}, {'remote': [1597.6019287109375, 1602.900146484375, 1665.95166015625, 1705.302734375], 'score': 0.7571285963058472}]

# %% [markdown]
# ## Display results

# %%
visualize_detections(image_path, detections)
